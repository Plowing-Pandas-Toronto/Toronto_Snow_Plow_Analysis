# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.12)
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/ekaterinaossetchkina/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ekaterinaossetchkina/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.26.7)
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/ekaterinaossetchkina/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import time
import pandas as pd
import json
from datetime import datetime

# %%
# Import 3rd party libraries, os (directory services), pandas (data manipulation), seaborn and matplotlib (for visualization)
import seaborn as sns
import matplotlib.pyplot as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
#new app
consumer_api_key = 'c5chcYjAYVYOz5ryGruYg1Vki'
consumer_api_secret = 'fpTt68oyv0hzBPthYo9RVNp44mEqmoe2gWxh664qgLkfzPJjt9'

# %%
callback_uri = 'oob' #

auth = tweepy.OAuthHandler(consumer_api_key,consumer_api_secret, callback_uri) #OAuth = standardized login into twitter server
redirect_url = auth.get_authorization_url() #get a URL can send twitter user to
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=7xZujgAAAAABbYS0AAABgCu2DVM

# %%
#update your pin into the variable user_pin below, as a string
user_pin = input('Provide your user pin from the link: ')
user_pin
# Out:
# Provide your user pin from the link: 8514124
# '8514124'

# %%
#retrieve access keys for the user, these do not change
#note: this cell can only be run once, otherwise a new pin must be retreived for security reasons
auth.get_access_token(user_pin)
# Out:
# ('1493257684451307533-JEIHy2UyGheRP2M51tz0miYjDs3Rab',
#  'aFYKaneRXaqRpfFJck6US3R0VE1PSHIPRp657aAWvvovo')

# %%
#gives access to everything in the twitter API
api = tweepy.API(auth)

# %% [markdown]
# ## Get list of tweets tagging @TO_WinterOps account

# %%
# Search full archive - searching from January start to end of March 2022
#note: there is a maximum of 100 tweets retreived with each API call
tweets_3_months = api.search_full_archive(label='dev', 
                           query='@TO_WinterOps',
                           fromDate="202201010000", 
                           toDate = "202203310000",
                           maxResults = 100
                           )

# %%
tweets_3_months
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Wed Mar 30 16:00:35 +0000 2022', 'id': 1509198916096561154, 'id_str': '1509198916096561154', 'text': 'RT @TO_WinterOps: Expressways, major roads, residential roads and trails are being salted where required.  #CityofTOWinterAlert @311Toronto', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 238984493, 'id_str': '238984493', 'name': 'TO Transportation', 'screen_name': 'TO_Transport', 'location': 'Toronto, Ontario, Canada', 'url': 'http://www.toronto.ca/transportation', 'description': 'Gateway to City of Toronto Transportation Services on Twitter. Please note, we do not provide responses at this account. Terms of Use: http://bit.ly/2CBLczr', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 9870, 'friends_count': 133, 'listed_count': 158, 'favourites_count': 3384, 'statuses_count': 9280, 'created_at': 'Sun Jan 16 14:27:59 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/456166797985579008/1X3slAH-_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/456166797985579008/1X3slAH-_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/238984493/1400010293', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Mar 30 15:32:26 +0000 2022', 'id': 1509191830394609674, 'id_str': '1509191830394609674', 'text': 'Expressways, major roads, residential roads and trails are being salted where required.  #CityofTOWinterAlert @311Toronto', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2319261674, 'id_str': '2319261674', 'name': 'TO Winter Operations', 'screen_name': 'TO_WinterOps', 'location': 'Toronto, Ontario, Canada', 'url': 'http://www.toronto.ca/plowTO', 'description': 'This account not monitored 24/7.  Messages posted to this account will not be responded to.  Call 311 to report winter related concerns.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 11241, 'friends_count': 91, 'listed_count': 165, 'favourites_count': 44, 'statuses_count': 2220, 'created_at': 'Thu Jan 30 17:17:32 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_im ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Wed Mar 30 15:39:56 +0000 2022', 'id': 1509193716531175428, 'id_str': '1509193716531175428', 'text': '@311Toronto @IndiainToronto @TO_WinterOps awaiting response for service request no. 00756498. The request was given… https://t.co/5hcMGjoior', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 24201621, 'in_reply_to_user_id_str': '24201621', 'in_reply_to_screen_name': '311Toronto', 'user': {'id': 151788596, 'id_str': '151788596', 'name': 'HEMANT SANGHVI', 'screen_name': 'Nanusanghvi', 'location': 'MUMBAI, INDIA', 'url': 'http://www.sanghvitools.com', 'description': 'Businessman. \nViews are personal...\nretweets are not necessarily endorsements', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 42, 'friends_count': 225, 'listed_count': 0, 'favourites_count': 924, 'statuses_count': 1681, 'created_at': 'Fri Jun 04 07:18:39 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3223029669/3ad18d5b82ac1c4b3f3de2992c71d92a_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3223029669/3ad18d5b82ac1c4b3f3de2992c71d92a_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@311Toronto @IndiainToronto @TO_WinterOps awaiting response for service request no. 00756498. The request was given couple of days back and the outside temp is below zero, which is very unpleasant inside with the heater not working. Expected an immediate action.', 'display_text_range': [0, 262], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [0, 11]}, {'screen_name': 'IndiainToronto', 'name': 'IndiainToronto', 'id': 4408147468, 'id_str': '4408147468', 'indices': [12, 27]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [28, 41]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 1, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/5hcMGjoior', 'expanded_url': 'https://twitter.com/i/web/status/1509193716531175428', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [0, 11]}, {'screen_name': 'IndiainToronto', 'name': 'IndiainToronto', 'id': 4408147468, 'id_str': '4408147468', 'indices': [12, 27]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [28, 41]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'matching_rules': [{'tag': None}]}, created_at=datetime.datetime(2022, 3, 30, 15, 39, 56, tzinfo=datetime.timezone.utc), id=1509193716531175428, id_str='1509193716531175428', text='@311Toronto @IndiainToronto @TO_WinterOps awaiting response for service request no. 00756498. The request was ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Tue Mar 29 16:52:47 +0000 2022', 'id': 1508849662442323980, 'id_str': '1508849662442323980', 'text': '@cath_devries This was the ONE major storm we had all winter which the incompetent snow clearing/removal slackers c… https://t.co/rYcWVNc4sQ', 'display_text_range': [14, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': 1508831849644240912, 'in_reply_to_status_id_str': '1508831849644240912', 'in_reply_to_user_id': 118569992, 'in_reply_to_user_id_str': '118569992', 'in_reply_to_screen_name': 'cath_devries', 'user': {'id': 915756919, 'id_str': '915756919', 'name': 'John McKellar', 'screen_name': 'JohnMcKellar2', 'location': None, 'url': None, 'description': "I'm a gay individual - not a perpetually peevish LGBTQ lemming.", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 462, 'friends_count': 828, 'listed_count': 1, 'favourites_count': 1846, 'statuses_count': 6626, 'created_at': 'Tue Oct 30 23:49:25 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/442821485611069441/U4IPuoiB_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/442821485611069441/U4IPuoiB_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/915756919/1539906680', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@cath_devries This was the ONE major storm we had all winter which the incompetent snow clearing/removal slackers couldn’t handle. The only reason we presently see no snow is due to natural melting. Meanwhile @JohnTory wants another term.🙄\n@cityoftoronto @TO_WinterOps', 'display_text_range': [14, 268], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'cath_devries', 'name': 'Catherine de Vries', 'id': 118569992, 'id_str': '118569992', 'indices': [0, 13]}, {'screen_name': 'JohnTory', 'name': 'John Tory', 'id': 89760824, 'id_str': '89760824', 'indices': [209, 218]}, {'screen_name': 'cityoftoronto', 'name': 'City of Toronto', 'id': 19377913, 'id_str': '19377913', 'indices': [240, 254]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [255, 268]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/rYcWVNc4sQ', 'expanded_url': 'https://twitter.com/i/web/status/1508849662442323980', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'cath_devries', 'name': 'Catherine de Vries', 'id': 118569992, 'id_str': '118569992', 'indices': [0, 13]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'matching_rules': [{'tag': None}]}, created_at=datetime.datetime(2022, 3, 29, 16, 52, 47, tzinfo=datetime.timezone.utc), id=1508849662442323980, id_str='1508849662442323980', text='@cath_devries This was the ONE major storm we had all winter which the incompetent snow clearing/removal slackers c… https://t.co/rYcWVNc4sQ', display_text_rang ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': '
normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/81900681/1465396837', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [0, 13]}, {'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [14, 25]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'matching_rules': [{'tag': None}]}, created_at=datetime.datetime(2022, 3, 23, 11, 14, 32, tzinfo=datetime.timezone.utc), id=1506590211987460097, id_str='1506590211987460097', text='@TO_WinterOps @311Toronto Is there any salting done yet today to tackle the forecasted freezing rain conditions?', source='Twitter Web App', source_url='https://mobile.twitter.com', truncated=False, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=2319261674, in_reply_to_user_id_str='2319261674', in_reply_to_screen_name='TO_WinterOps', author=User(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'id': 81900681, 'id_str': '81900681', 'name': 'BD Idol', 'screen_name': 'bdidol', 'location': 'Canada', 'url': 'http://www.facebook.com/bdidolx', 'description': '||Life is-as it is|| \nHuman Rights Activist, Blogger.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1649, 'friends_count': 420, 'listed_count': 3, 'favourites_count': 1349, 'statuses_count': 16064, 'created_at': 'Mon Oct 12 18:43:24 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'EBEBEB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif', 'profile_background_image_url_ ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Wed Mar 16 13:09:34 +0000 2022', 'id': 1504082448954667011, 'id_str': '1504082448954667011', 'text': '@TO_WinterOps Wondering why we needed to salt roads &amp; plow/salt sidewalks, when projected +2C all last night? Seems… https://t.co/YzdpMxwGzf', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 2319261674, 'in_reply_to_user_id_str': '2319261674', 'in_reply_to_screen_name': 'TO_WinterOps', 'user': {'id': 14462273, 'id_str': '14462273', 'name': 'B. Chill Copywriting', 'screen_name': 'hillcopywriting', 'location': 'Toronto, Canada', 'url': None, 'description': 'Chosen by Ogilvy to write Dove "Real Beauty" ads, also for The Economist & Disney HK Park launch. Lover of Science, Creativity & Philosophy. Car nut. MBA, Ivey', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 343, 'friends_count': 1005, 'listed_count': 12, 'favourites_count': 102, 'statuses_count': 435, 'created_at': 'Mon Apr 21 14:28:33 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': True, 'profile_link_color': '0099CC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F6FFD1', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1317306506774237186/4Il6230a_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317306506774237186/4Il6230a_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14462273/1466386940', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@TO_WinterOps Wondering why we needed to salt roads &amp; plow/salt sidewalks, when projected +2C all last night? Seems like an extremely egregious and conspicuous waste of fuel (very anti-environment), overtime, and wear-&amp;-tear on machinery @JoshMatlow @cityoftoronto @JohnTory', 'display_text_range': [0, 282], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [0, 13]}, {'screen_name': 'JoshMatlow', 'name': 'Josh Matlow', 'id': 15844405, 'id_str': '15844405', 'indices': [246, 257]}, {'screen_name': 'cityoftoronto', 'name': 'City of Toronto', 'id': 19377913, 'id_str': '19377913', 'indices': [258, 272]}, {'screen_name': 'JohnTory', 'name': 'John Tory', 'id': 89760824, 'id_str': '89760824', 'indices': [273, 282]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/YzdpMxwGzf', 'expanded_url': 'https://twitter.com/i/web/status/1504082448954667011', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}], 'user_mentions': [{'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [0, 13]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'matching_rules': [{'tag': None}]}, created_at=datetime.datetime(2022, 3, 16, 13, 9, 34, tzinfo=datetime.timezone.utc), id=1504082448954667011, id_str='1504082448954667011', text='@TO_WinterOps Wondering why we needed to salt roads &amp; plow/salt sidewalks, when projected +2C  ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Tue Mar 15 23:15:28 +0000 2022', 'id': 1503872538480463874, 'id_str': '1503872538480463874', 'text': 'RT @TO_WinterOps: Winter operations are ongoing. Road salting, clearing of sidewalks and bikeways and salting of  bus stops and crosswalks…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
+0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/458581133098110978/9Ka1LKCG_normal.png', 'profile_i ...
#  Status(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'created_at': 'Fri Feb 18 08:37:49 +0000 2022', 'id': 1494591972417417220, 'id_str': '1494591972417417220', 'text': '@FelixT2021 @TO_WinterOps @311Toronto Same! M4G area.', 'display_text_range': [38, 53], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': 1494542501893529624, 'in_reply_to_status_id_str': '1494542501893529624', 'in_reply_to_user_id': 1229615676605829122, 'in_reply_to_user_id_str': '1229615676605829122', 'in_reply_to_screen_name': 'FelixT2021', 'user': {'id': 4086986122, 'id_str': '4086986122', 'name': 'heh 🇺🇦', 'screen_name': 'hehhehhyohyo', 'location': 'YYZ, YEG, YHZ, YYG, ICN.', 'url': None, 'description': 'ANTI-CAR PROPAGANDA BOT. \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000BAN (THEM F*CKING) CARS.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 323, 'friends_count': 647, 'listed_count': 53, 'favourites_count': 47915, 'statuses_count': 23674, 'created_at': 'Sun Nov 01 02:50:39 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1447720130251825154/DFsYskFf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1447720130251825154/DFsYskFf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4086986122/1637190076', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'FelixT2021', 'name': 'Felix', 'id': 1229615676605829122, 'id_str': '1229615676605829122', 'indices': [0, 11]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [12, 25]}, {'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [26, 37]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'matching_rules': [{'tag': None}]}, created_at=datetime.datetime(2022, 2, 18, 8, 37, 49, tzinfo=datetime.timezone.utc), id=1494591972417417220, id_str='1494591972417417220', text='@FelixT2021 @TO_WinterOps @311Toronto Same! M4G area.', display_text_range=[38, 53], source='Twitter for Android', source_url='http://twitter.com/download/android', truncated=False, in_reply_to_status_id=1494542501893529624, in_reply_to_status_id_str='1494542501893529624', in_reply_to_user_id=1229615676605829122, in_reply_to_user_id_str='1229615676605829122', in_reply_to_screen_name='FelixT2021', author=User(_api=<tweepy.api.API object at 0x7fe4cb917400>, _json={'id': 4086986122, 'id_str': '4086986122', 'name': 'heh 🇺🇦', 'screen_name': 'hehhehhyohyo', 'location': 'YYZ, YEG, YHZ, YYG, ICN.', 'url': None, 'description': 'ANTI-CAR PROPAGANDA BOT. \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u30 ...

# %%
# To get a meaningful output, use this loop to print the first 5 entries:
for info in tweets_3_months[:5]:
     print("ID: {}".format(info.id))
     print(info.created_at)
     print(info.text)
     print(info.entities)
     print(info.user.screen_name)
     print(info.user.id)
     print("\n")
# Out:
# ID: 1482783656792018946
# 2022-01-16 18:35:47+00:00
# RT @clairejoswald: Applying salt brine before a snowfall is a good way to reduce overall road salt application rates. Good luck with this s…
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'clairejoswald', 'name': 'Dr. Claire J. Oswald', 'id': 930466742, 'id_str': '930466742', 'indices': [3, 17]}], 'symbols': []}
# LostRiversTO
# 778920158
#
#
# ID: 1482766485181370369
# 2022-01-16 17:27:33+00:00
# Applying salt brine before a snowfall is a good way to reduce overall road salt application rates. Good luck with t… https://t.co/OsMtswoqIx
# {'hashtags': [], 'urls': [{'url': 'https://t.co/OsMtswoqIx', 'expanded_url': 'https://twitter.com/i/web/status/1482766485181370369', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []}
# clairejoswald
# 930466742
#
#
# ID: 1482738550709784581
# 2022-01-16 15:36:33+00:00
# @markhmills @cityoftoronto @JohnTory @TO_WinterOps @TO_Transport Is it electric?
# {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'markhmills', 'name': 'Mark Mills', 'id': 261944455, 'id_str': '261944455', 'indices': [0, 11]}, {'screen_name': 'cityoftoronto', 'name': 'City of Toronto', 'id': 19377913, 'id_str': '19377913', 'indices': [12, 26]}, {'screen_name': 'JohnTory', 'name': 'John Tory', 'id': 89760824, 'id_str': '89760824', 'indices': [27, 36]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [37, 50]}, {'screen_name': 'TO_Transport', 'name': 'TO Transportation', 'id': 238984493, 'id_str': '238984493', 'indices': [51, 64]}], 'symbols': []}
# georgebell
# 21597493
#
#
# ID: 1482556691283591168
# 2022-01-16 03:33:54+00:00
# @warrenhuska @markhmills @cityoftoronto @JohnTory @TO_WinterOps @TO_Transport THE BIKE LANE YOU CLOWN!!! PEDESTRIAN… https://t.co/cv1YsE5rKM
# {'hashtags': [], 'urls': [{'url': 'https://t.co/cv1YsE5rKM', 'expanded_url': 'https://twitter.com/i/web/status/1482556691283591168', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'warrenhuska', 'name': 'Warren Huska', 'id': 18952341, 'id_str': '18952341', 'indices': [0, 12]}, {'screen_name': 'markhmills', 'name': 'Mark Mills', 'id': 261944455, 'id_str': '261944455', 'indices': [13, 24]}, {'screen_name': 'cityoftoronto', 'name': 'City of Toronto', 'id': 19377913, 'id_str': '19377913', 'indices': [25, 39]}, {'screen_name': 'JohnTory', 'name': 'John Tory', 'id': 89760824, 'id_str': '89760824', 'indices': [40, 49]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [50, 63]}, {'screen_name': 'TO_Transport', 'name': 'TO Transportation', 'id': 238984493, 'id_str': '238984493', 'indices': [64, 77]}], 'symbols': []}
# E_R0z1E
# 1447713171381399560
#
#
# ID: 1482556344376999937
# 2022-01-16 03:32:31+00:00
# @warrenhuska @markhmills @cityoftoronto @JohnTory @TO_WinterOps @TO_Transport Sidewalks should be city responsibili… https://t.co/nB22WHAKV8
# {'hashtags': [], 'urls': [{'url': 'https://t.co/nB22WHAKV8', 'expanded_url': 'https://twitter.com/i/web/status/1482556344376999937', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'warrenhuska', 'name': 'Warren Huska', 'id': 18952341, 'id_str': '18952341', 'indices': [0, 12]}, {'screen_name': 'markhmills', 'name': 'Mark Mills', 'id': 261944455, 'id_str': '261944455', 'indices': [13, 24]}, {'screen_name': 'cityoftoronto', 'name': 'City of Toronto', 'id': 19377913, 'id_str': '19377913', 'indices': [25, 39]}, {'screen_name': 'JohnTory', 'name': 'John Tory', 'id': 89760824, 'id_str': '89760824', 'indices': [40, 49]}, {'screen_name': 'TO_WinterOps', 'name': 'TO Winter Operations', 'id': 2319261674, 'id_str': '2319261674', 'indices': [50, 63]}, {'screen_name': 'TO_Transport', 'name': 'TO Transportation', 'id': 238984493, 'id_str': '238984493', 'indices': [64, 77]}], 'symbols': []}
# E_R0z1E
# 1447713171381399560

# %%
#Due to the 100 Tweet pull, we did not pull all the way back to January. The minimum date can be found like so:
min_date = (str(tweets_3_months[-1].created_at)[0:10]).replace('-','')+'0000'
print(min_date)
# Out:
# 202201010000

# %%
# To download all tweets, not just the last 100: 
tweets_3_months = api.search_full_archive(label='dev', 
                           query='@TO_WinterOps',
                           fromDate="202201010000", 
                           toDate = "202203310000",
                           maxResults = 100
                           )

all_mentions = []
all_mentions.extend(tweets_3_months)
while True:
    tweets_3_months = api.search_full_archive(label='dev', 
                           query='@TO_WinterOps',
                           fromDate="202201010000", 
                           toDate = min_date,
                           maxResults = 100
                           )
    if len(tweets_3_months) == 0:
        break
        
    min_date = (str(tweets_3_months[-1].created_at)[0:10]).replace('-','')+'0000'
    print(min_date)
    all_mentions.extend(tweets_3_months)
    print('Number of tweets in all_mentions dataframe: {}'.format(len(all_mentions)))

#The loop will break when either the length of a new API pull has zero tweets, or when the toDate equals the fromDate

# %%
from pandas import DataFrame

mentions_tweets = [[ info.id, 
              info.created_at, 
              info.favorite_count, 
              info.retweet_count, 
              info.text.encode("utf-8").decode("utf-8"),
              info.entities,
              info.user.screen_name] 
             for idx,info in enumerate(all_mentions)]
mentions_df = DataFrame(mentions_tweets,columns=["id","created_at","favorite_count","retweet_count", "text", "entities","screen_name"])
mentions_df.head()
# Out:
#                     id                created_at  favorite_count  \
# 0  1509198916096561154 2022-03-30 16:00:35+00:00               0
# 1  1509193716531175428 2022-03-30 15:39:56+00:00               0
# 2  1508849662442323980 2022-03-29 16:52:47+00:00               0
# 3  1508176549899550729 2022-03-27 20:18:04+00:00               0
# 4  1508108574777614347 2022-03-27 15:47:58+00:00               0
#
#    retweet_count                                               text  \
# 0              0  RT @TO_WinterOps: Expressways, major roads, re...
# 1              0  @311Toronto @IndiainToronto @TO_WinterOps awai...
# 2              0  @cath_devries This was the ONE major storm we ...
# 3              0  RT @TO_WinterOps: All expressways, main roads ...
# 4              0  RT @TO_WinterOps: All expressways, main roads ...
#
#                                             entities     screen_name
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...    TO_Transport
# 1  {'hashtags': [], 'urls': [{'url': 'https://t.c...     Nanusanghvi
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...   JohnMcKellar2
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  midweekcycling
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...     TPSAux14Div

# %% [markdown]
# Now all the tweets are in the dataframe. Note, that with the Elevated Academic license, when using the Full Archive Search API twitter will limit the number of characters in the tweet (showing 180 characters out of the possible 280 limit).
#
# To retrieve the full tweet text, an Enterprise paid license is required, which was not done for this project.

# %%
#to follow along with the code, the dataframe will be saved to a separate file all_mentions.csv
mentions_df.to_csv('src/Twitter Data/mentions.csv')

mentions_df = pd.read_csv('src/Twitter Data/mentions.csv')
mentions_df.head()
# Out:
#              id                 created_at  favorite_count  retweet_count  \
# 0  1.509200e+18  2022-03-30 16:00:35+00:00               0              0
# 1  1.509190e+18  2022-03-30 15:39:56+00:00               0              0
# 2  1.508850e+18  2022-03-29 16:52:47+00:00               0              0
# 3  1.508180e+18  2022-03-27 20:18:04+00:00               0              0
# 4  1.508110e+18  2022-03-27 15:47:58+00:00               0              0
#
#                                                 text  \
# 0  rt @to_winterops: expressways, major roads, re...
# 1  @311toronto @indiaintoronto @to_winterops awai...
# 2  @cath_devries this was the one major storm we ...
# 3  rt @to_winterops: all expressways, main roads ...
# 4  rt @to_winterops: all expressways, main roads ...
#
#                                             entities     screen_name
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...    TO_Transport
# 1  {'hashtags': [], 'urls': [{'url': 'https://t.c...     Nanusanghvi
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...   JohnMcKellar2
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  midweekcycling
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...     TPSAux14Div

# %%
#Data-frame cleanup and date-time localization
mentions_df['datetime_utc'] = pd.to_datetime(mentions_df['created_at'],utc=True)
mentions_df['datetime_est'] = mentions_df['datetime_utc'].dt.tz_convert('US/Eastern')

# %%
mentions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              864 non-null    float64
#  1   created_at      864 non-null    object
#  2   favorite_count  864 non-null    int64
#  3   retweet_count   864 non-null    int64
#  4   text            864 non-null    object
#  5   entities        864 non-null    object
#  6   screen_name     864 non-null    object
#  7   datetime_utc    864 non-null    datetime64[ns, UTC]
#  8   datetime_est    864 non-null    datetime64[ns, US/Eastern]
# dtypes: datetime64[ns, US/Eastern](1), datetime64[ns, UTC](1), float64(1), int64(2), object(4)
# memory usage: 60.9+ KB

# %% [markdown]
# ## Preparing dataframe for sentiment analysis

# %%
mentions_df['text'] = mentions_df['text'].str.lower()

# %%
#The list of all punctuations to be removed
punctuations = '!"#$%&\'()*+,-./:;<=>?@@[\\]^_`{|}~“' 

def remove_punctuations(text):
    for x in punctuations:
         if (x in text):
            text=text.replace(x," ")
    return text

mentions_df['text_no_punc'] = mentions_df.apply(lambda row: remove_punctuations(text=row['text']),axis=1)

# View DataFrame
mentions_df.head()
# Out:
#              id                 created_at  favorite_count  retweet_count  \
# 0  1.509200e+18  2022-03-30 16:00:35+00:00               0              0
# 1  1.509190e+18  2022-03-30 15:39:56+00:00               0              0
# 2  1.508850e+18  2022-03-29 16:52:47+00:00               0              0
# 3  1.508180e+18  2022-03-27 20:18:04+00:00               0              0
# 4  1.508110e+18  2022-03-27 15:47:58+00:00               0              0
#
#                                                 text  \
# 0  rt @to_winterops: expressways, major roads, re...
# 1  @311toronto @indiaintoronto @to_winterops awai...
# 2  @cath_devries this was the one major storm we ...
# 3  rt @to_winterops: all expressways, main roads ...
# 4  rt @to_winterops: all expressways, main roads ...
#
#                                             entities     screen_name  \
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...    TO_Transport
# 1  {'hashtags': [], 'urls': [{'url': 'https://t.c...     Nanusanghvi
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...   JohnMcKellar2
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  midweekcycling
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...     TPSAux14Div
#
#                datetime_utc              datetime_est  \
# 0 2022-03-30 16:00:35+00:00 2022-03-30 12:00:35-04:00
# 1 2022-03-30 15:39:56+00:00 2022-03-30 11:39:56-04:00
# 2 2022-03-29 16:52:47+00:00 2022-03-29 12:52:47-04:00
# 3 2022-03-27 20:18:04+00:00 2022-03-27 16:18:04-04:00
# 4 2022-03-27 15:47:58+00:00 2022-03-27 11:47:58-04:00
#
#                                         text_no_punc
# 0  rt  to winterops  expressways  major roads  re...
# 1   311toronto  indiaintoronto  to winterops awai...
# 2   cath devries this was the one major storm we ...
# 3  rt  to winterops  all expressways  main roads ...
# 4  rt  to winterops  all expressways  main roads ...

# %%
mentions_df = mentions_df.set_index('id')
mentions_df.head()
# Out:
#                              created_at  favorite_count  retweet_count  \
# id
# 1.509200e+18  2022-03-30 16:00:35+00:00               0              0
# 1.509190e+18  2022-03-30 15:39:56+00:00               0              0
# 1.508850e+18  2022-03-29 16:52:47+00:00               0              0
# 1.508180e+18  2022-03-27 20:18:04+00:00               0              0
# 1.508110e+18  2022-03-27 15:47:58+00:00               0              0
#
#                                                            text  \
# id
# 1.509200e+18  rt @to_winterops: expressways, major roads, re...
# 1.509190e+18  @311toronto @indiaintoronto @to_winterops awai...
# 1.508850e+18  @cath_devries this was the one major storm we ...
# 1.508180e+18  rt @to_winterops: all expressways, main roads ...
# 1.508110e+18  rt @to_winterops: all expressways, main roads ...
#
#                                                        entities  \
# id
# 1.509200e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
# 1.509190e+18  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1.508850e+18  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1.508180e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
# 1.508110e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
#
#                  screen_name              datetime_utc  \
# id
# 1.509200e+18    TO_Transport 2022-03-30 16:00:35+00:00
# 1.509190e+18     Nanusanghvi 2022-03-30 15:39:56+00:00
# 1.508850e+18   JohnMcKellar2 2022-03-29 16:52:47+00:00
# 1.508180e+18  midweekcycling 2022-03-27 20:18:04+00:00
# 1.508110e+18     TPSAux14Div 2022-03-27 15:47:58+00:00
#
#                           datetime_est  \
# id
# 1.509200e+18 2022-03-30 12:00:35-04:00
# 1.509190e+18 2022-03-30 11:39:56-04:00
# 1.508850e+18 2022-03-29 12:52:47-04:00
# 1.508180e+18 2022-03-27 16:18:04-04:00
# 1.508110e+18 2022-03-27 11:47:58-04:00
#
#                                                    text_no_punc
# id
# 1.509200e+18  rt  to winterops  expressways  major roads  re...
# 1.509190e+18   311toronto  indiaintoronto  to winterops awai...
# 1.508850e+18   cath devries this was the one major storm we ...
# 1.508180e+18  rt  to winterops  all expressways  main roads ...
# 1.508110e+18  rt  to winterops  all expressways  main roads ...

# %%
#Each word from the tweets will be separated into its own row in a new dataframe
word_lookup = (mentions_df['text_no_punc'].str.split(' ', expand=True).stack().reset_index(name='word'))
word_lookup = word_lookup[word_lookup.word != '']
word_lookup = word_lookup.set_index('id',drop=True).rename(columns={'level_1':'num'})

word_lookup.head()
# Out:
#               num         word
# id
# 1.509200e+18    0           rt
# 1.509200e+18    2           to
# 1.509200e+18    3    winterops
# 1.509200e+18    5  expressways
# 1.509200e+18    7        major

# %% [markdown]
# ## Lexicon import and join

# %%
#Original data source: https://github.com/cjhutto/vaderSentiment

file = open('src/Twitter Data/vader_lexicon.txt', 'r').read().split('\n')
lexicon_text = [x for x in file[0:]]

lexicon =  pd.DataFrame(lexicon_text,columns=['data'])
lexicon = lexicon['data'].str.split('\t',expand=True)
lexicon = lexicon[[0,1]].rename(columns={0: "word", 1: "polarity"}).set_index('word')

# View DataFrame
lexicon.head()
# Out:
#      polarity
# word
# $:       -1.5
# %)       -0.4
# %-)      -1.5
# &-:      -0.4
# &:       -0.7

# %%
#The lexicon is looked up on each word to assign a polarity value
word_lookup = word_lookup.join(lexicon, on ='word')
word_lookup.fillna(0, inplace=True)

# View DataFrame
word_lookup.head()
# Out:
#               num         word polarity
# id
# 1.509200e+18    0           rt        0
# 1.509200e+18    2           to        0
# 1.509200e+18    3    winterops        0
# 1.509200e+18    5  expressways        0
# 1.509200e+18    7        major        0

# %%
word_lookup[["polarity"]] = word_lookup[["polarity"]].apply(pd.to_numeric)
polarity = word_lookup.groupby(['id'])['polarity'].sum().to_frame()

# View DataFrame
polarity.head()
# Out:
#               polarity
# id
# 1.477110e+18       0.0
# 1.477400e+18       0.0
# 1.477480e+18       0.0
# 1.477490e+18       0.0
# 1.477610e+18       2.5

# %%
#The dataframe mentions_df is combined with the dataframe polarity using the join function on the column 'id'.
mentions_df = mentions_df.join(polarity,on='id')

# View DataFrame
mentions_df.head()
# Out:
#                              created_at  favorite_count  retweet_count  \
# id
# 1.509200e+18  2022-03-30 16:00:35+00:00               0              0
# 1.509190e+18  2022-03-30 15:39:56+00:00               0              0
# 1.508850e+18  2022-03-29 16:52:47+00:00               0              0
# 1.508180e+18  2022-03-27 20:18:04+00:00               0              0
# 1.508110e+18  2022-03-27 15:47:58+00:00               0              0
#
#                                                            text  \
# id
# 1.509200e+18  rt @to_winterops: expressways, major roads, re...
# 1.509190e+18  @311toronto @indiaintoronto @to_winterops awai...
# 1.508850e+18  @cath_devries this was the one major storm we ...
# 1.508180e+18  rt @to_winterops: all expressways, main roads ...
# 1.508110e+18  rt @to_winterops: all expressways, main roads ...
#
#                                                        entities  \
# id
# 1.509200e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
# 1.509190e+18  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1.508850e+18  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1.508180e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
# 1.508110e+18  {'hashtags': [{'text': 'CityofTOWinterAlert', ...
#
#                  screen_name              datetime_utc  \
# id
# 1.509200e+18    TO_Transport 2022-03-30 16:00:35+00:00
# 1.509190e+18     Nanusanghvi 2022-03-30 15:39:56+00:00
# 1.508850e+18   JohnMcKellar2 2022-03-29 16:52:47+00:00
# 1.508180e+18  midweekcycling 2022-03-27 20:18:04+00:00
# 1.508110e+18     TPSAux14Div 2022-03-27 15:47:58+00:00
#
#                           datetime_est  \
# id
# 1.509200e+18 2022-03-30 12:00:35-04:00
# 1.509190e+18 2022-03-30 11:39:56-04:00
# 1.508850e+18 2022-03-29 12:52:47-04:00
# 1.508180e+18 2022-03-27 16:18:04-04:00
# 1.508110e+18 2022-03-27 11:47:58-04:00
#
#                                                    text_no_punc  polarity
# id
# 1.509200e+18  rt  to winterops  expressways  major roads  re...       0.0
# 1.509190e+18   311toronto  indiaintoronto  to winterops awai...      -1.2
# 1.508850e+18   cath devries this was the one major storm we ...      -2.1
# 1.508180e+18  rt  to winterops  all expressways  main roads ...       0.0
# 1.508110e+18  rt  to winterops  all expressways  main roads ...       0.0

# %%
#Tweets are rounded for aggegation
mentions_df['datetime_rounded'] = mentions_df['datetime_est'].dt.round('H')

# %%
#Assign positive, neutral and negative values for later aggregation

mentions_df['final_polarity'] = mentions_df['polarity'].apply(lambda x: 'Postive' if x > 0 else ('Neutral' if x == 0 else 'Negative'))
mentions_df['final_polarity'].value_counts()
# Out:
# Postive     541
# Negative    164
# Neutral     159
# Name: final_polarity, dtype: int64

# %%
#Saving dataframe with polarity, to combine with weather data in the next notebook

mentions_df.to_csv('src/Twitter Data/mentions_polarity.csv')

# %%
print("Most negative tweets at the city, January to March 2022:")
for text in mentions_df.sort_values('polarity').head(10)['text']:
    print('\n  ', text)
# Out:
# Most negative tweets at the city, January to March 2022:
#
#    @stoptionalto @johntory @teamfilion23 across the city sidewalks &amp; bikeways are neglected where snow plows pushed sn… https://t.co/rpgqut27fz
#
#    @wardforpeople @johntory @teamfilion23 @to_winterops aye! so dangerous!!! why are our kids dead last all.the.damn.t… https://t.co/1vls4xy2ls
#
#    rt @wardforpeople: @stoptionalto @johntory @teamfilion23 across the city sidewalks &amp; bikeways are neglected where snow plows pushed snow in…
#
#    @amazonjb @notsafe4bikesto @to_winterops @cycletoronto @311toronto @johntory this is a scary one to bike right now… https://t.co/rmpkv5pnvp
#
#    @to_winterops @311toronto the sidewalks at strachan and adelaide are still really bad and only going to get worse with the snow this week.
#
#    @to_winterops @311toronto some are being missed, plow drivers are too stupid and lazy to realize people can't leave… https://t.co/kfrmputf1g
#
#    @ostrawczy @to_winterops i know.   no plows.  i checked.
#
#    @to_winterops @311toronto @cityoftoronto snow plow just went thru my neighborhood (pine point etobicoke) for 10 min… https://t.co/vlsafkjokm
#
#    @311toronto @lizabutcher @to_winterops however it doesn't mean they do anything, it just means they did a drive-by… https://t.co/ekehfdyqxj
#
#    @311toronto this ice needs to be cleaned up before someone falls on it and gets hurt. wtf @to_winterops
#
# bloor wb,… https://t.co/asnxdadwup

# %%
from matplotlib.dates import DateFormatter

#Visualization of tweet polarity over time
plt.figure(figsize=(15, 4))

plt.title('Polarity of Tweets tagging @TO_WinterOps', fontsize=18)
ax = sns.barplot(data=mentions_df, x='datetime_est', y='polarity',palette="crest")

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=14)
ax.set_ylabel('Polarity', fontsize=18)
#date_form = DateFormatter("%m-%d")

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Get list of tweets from the @TO_WinterOps account

# %%
# we will be using the user_time API to get all tweets from the @TO_WinterOps account from Jan-March
userID = 'TO_WinterOps'

# Authorize our Twitter credentials
tweets = api.user_timeline(screen_name=userID, 
                           count=200,
                           include_rts = False,
                           tweet_mode = 'extended' #will include the full tweet text
                           )

# %%
#similar to earlier, to download more historic tweets, not just the last 200 (API limit for user_limit)
all_tweets = []
all_tweets.extend(tweets)
oldest_id = tweets[-1].id #the earliest id is extracted, which will be used to compare in the loop

while True:
    tweets = api.user_timeline(screen_name=userID, 
                           count=200,
                           include_rts = False,
                           max_id = oldest_id - 1, #generate a new latest id based on previous API call
                           tweet_mode = 'extended'
                           )
    if len(tweets) == 0:
        break
    oldest_id = tweets[-1].id
    all_tweets.extend(tweets)
    print('Number of tweets downloaded {}'.format(len(all_tweets)))
# Out:
# Number of tweets downloaded 319
# Number of tweets downloaded 459
# Number of tweets downloaded 623
# Number of tweets downloaded 811
# Number of tweets downloaded 976
# Number of tweets downloaded 1142
# Number of tweets downloaded 1292
# Number of tweets downloaded 1485
# Number of tweets downloaded 1682
# Number of tweets downloaded 1862
# Number of tweets downloaded 1886

# %%
# print out the latest 5 tweets
for info in all_tweets[:5]:
    print("ID: {}".format(info.id))
    print(info.created_at)
    print(info.full_text)
    print(info.entities)
    print(info.user.screen_name)
    print(info.user.id)
    print("\n")
# Out:
# ID: 1510379455432245248
# 2022-04-02 22:11:38+00:00
# Liquid salt brine is being applied to Hills, bridges and roads throughout the City.  #CityofTOWinterAlert @311Toronto
# {'hashtags': [{'text': 'CityofTOWinterAlert', 'indices': [85, 105]}], 'symbols': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [106, 117]}], 'urls': []}
# TO_WinterOps
# 2319261674
#
#
# ID: 1509191830394609674
# 2022-03-30 15:32:26+00:00
# Expressways, major roads, residential roads and trails are being salted where required.  #CityofTOWinterAlert @311Toronto
# {'hashtags': [{'text': 'CityofTOWinterAlert', 'indices': [89, 109]}], 'symbols': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [110, 121]}], 'urls': []}
# TO_WinterOps
# 2319261674
#
#
# ID: 1509001347986821121
# 2022-03-30 02:55:31+00:00
# Liquid salt brine is being applied to expressways and major roads #CityofTOWinterAlert @311Toronto
# {'hashtags': [{'text': 'CityofTOWinterAlert', 'indices': [66, 86]}], 'symbols': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [87, 98]}], 'urls': []}
# TO_WinterOps
# 2319261674
#
#
# ID: 1508072929841528836
# 2022-03-27 13:26:19+00:00
# All expressways, main roads and bikeways are being salted. #CityofTOWinterAlert @311Toronto
# {'hashtags': [{'text': 'CityofTOWinterAlert', 'indices': [59, 79]}], 'symbols': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [80, 91]}], 'urls': []}
# TO_WinterOps
# 2319261674
#
#
# ID: 1503870532986589186
# 2022-03-15 23:07:30+00:00
# Winter operations are ongoing. Road salting, clearing of sidewalks and bikeways and salting of  bus stops and crosswalks continue tonight.  #CityofTOWinterAlert @311Toronto
# {'hashtags': [{'text': 'CityofTOWinterAlert', 'indices': [140, 160]}], 'symbols': [], 'user_mentions': [{'screen_name': '311Toronto', 'name': '311 Toronto', 'id': 24201621, 'id_str': '24201621', 'indices': [161, 172]}], 'urls': []}
# TO_WinterOps
# 2319261674

# %%
#same as earlier for mentions, generate a data frame from City tweets
TO_tweets = [[
              tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8"),
              tweet.entities,
              tweet.user.screen_name] 
             for idx,tweet in enumerate(all_tweets)]
to_tweets = DataFrame(TO_tweets ,columns=["id","created_at","favorite_count","retweet_count", "text", "entities","screen_name"])
to_tweets.head()
# Out:
#                     id                created_at  favorite_count  \
# 0  1510379455432245248 2022-04-02 22:11:38+00:00               1
# 1  1509191830394609674 2022-03-30 15:32:26+00:00               3
# 2  1509001347986821121 2022-03-30 02:55:31+00:00               5
# 3  1508072929841528836 2022-03-27 13:26:19+00:00               8
# 4  1503870532986589186 2022-03-15 23:07:30+00:00               4
#
#    retweet_count                                               text  \
# 0              1  Liquid salt brine is being applied to Hills, b...
# 1              1  Expressways, major roads, residential roads an...
# 2              0  Liquid salt brine is being applied to expressw...
# 3              5  All expressways, main roads and bikeways are b...
# 4              2  Winter operations are ongoing. Road salting, c...
#
#                                             entities   screen_name
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 1  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 2  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps

# %%
#to follow along with the code, the dataframe will be saved to a separate file to_tweets.csv
to_tweets.to_csv('src/Twitter Data/to_tweets.csv')

to_tweets = pd.read_csv('src/Twitter Data/to_tweets.csv')
to_tweets.head()
# Out:
#    Unnamed: 0                   id                 created_at  favorite_count  \
# 0           0  1510379455432245248  2022-04-02 22:11:38+00:00               1
# 1           1  1509191830394609674  2022-03-30 15:32:26+00:00               3
# 2           2  1509001347986821121  2022-03-30 02:55:31+00:00               5
# 3           3  1508072929841528836  2022-03-27 13:26:19+00:00               8
# 4           4  1503870532986589186  2022-03-15 23:07:30+00:00               4
#
#    retweet_count                                               text  \
# 0              1  Liquid salt brine is being applied to Hills, b...
# 1              1  Expressways, major roads, residential roads an...
# 2              0  Liquid salt brine is being applied to expressw...
# 3              5  All expressways, main roads and bikeways are b...
# 4              2  Winter operations are ongoing. Road salting, c...
#
#                                             entities   screen_name
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 1  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 2  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps

# %%
to_tweets['datetime_utc'] = pd.to_datetime(to_tweets['created_at'],utc=True)
to_tweets['datetime_est'] = to_tweets['datetime_utc'].dt.tz_convert('US/Eastern')
to_tweets.head()
# Out:
#    Unnamed: 0                   id                 created_at  favorite_count  \
# 0           0  1510379455432245248  2022-04-02 22:11:38+00:00               1
# 1           1  1509191830394609674  2022-03-30 15:32:26+00:00               3
# 2           2  1509001347986821121  2022-03-30 02:55:31+00:00               5
# 3           3  1508072929841528836  2022-03-27 13:26:19+00:00               8
# 4           4  1503870532986589186  2022-03-15 23:07:30+00:00               4
#
#    retweet_count                                               text  \
# 0              1  Liquid salt brine is being applied to Hills, b...
# 1              1  Expressways, major roads, residential roads an...
# 2              0  Liquid salt brine is being applied to expressw...
# 3              5  All expressways, main roads and bikeways are b...
# 4              2  Winter operations are ongoing. Road salting, c...
#
#                                             entities   screen_name  \
# 0  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 1  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 2  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 3  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
# 4  {'hashtags': [{'text': 'CityofTOWinterAlert', ...  TO_WinterOps
#
#                datetime_utc              datetime_est
# 0 2022-04-02 22:11:38+00:00 2022-04-02 18:11:38-04:00
# 1 2022-03-30 15:32:26+00:00 2022-03-30 11:32:26-04:00
# 2 2022-03-30 02:55:31+00:00 2022-03-29 22:55:31-04:00
# 3 2022-03-27 13:26:19+00:00 2022-03-27 09:26:19-04:00
# 4 2022-03-15 23:07:30+00:00 2022-03-15 19:07:30-04:00

# %%
to_tweets.to_csv('src/Twitter Data/to_tweets_final.csv')

# %%
# Sort data and visualize re-tweets in January and February
to_tweets['year'] = to_tweets['datetime_utc'].dt.year
to_tweets['month'] = to_tweets['datetime_utc'].dt.month

year = to_tweets[to_tweets['year']==2022]

retweets = year.groupby('month').agg(count=('retweet_count', 'sum'))
retweets.reset_index()
retweets['Month']=retweets.index
retweets=retweets[(retweets['Month']<=3)]
retweets['mm'] = retweets['Month'].apply(lambda x: 'January' if x == 1 else ('February' if x == 2 else 'March'))
retweets = retweets[(retweets['Month']==1) | (retweets['Month']==2)]
retweets.head()
# Out:
#        count  Month        mm
# month
# 1         29      1   January
# 2         73      2  February

# %%
#retweet count over time - increase in Toronto citizens resharing weather warnings and city updates
plt.figure(figsize=(8, 4))

plt.title('Retweets from TO_WinterOps Account', fontsize=18)
ax = sns.barplot(data=retweets, x='mm', y='count',palette="crest")

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Month', fontsize=18)
ax.set_ylabel('Retweet Count', fontsize=18)
plt.xticks(rotation = 0)
plt.show()
